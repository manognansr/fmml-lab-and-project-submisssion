# %% [markdown]
# <a href="https://colab.research.google.com/github/manognansr/fmml-lab-and-project-submisssion/blob/main/Module8_Lab3_fmml20210295.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-16 15:08:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   104MB/s    in 0.7s
#
# 2022-06-16 15:08:44 (104 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14123  1711.10354v1  Deep learning has been successfully applied in...    cs
# 9643   1612.06176v1  The Perona-Malik model has been very successfu...    cs
# 12010  1706.01833v1  In this work, we design a machine learning bas...  stat
# 16344  1701.03214v2  In this paper, we propose a novel domain adapt...    cs
# 37972   0810.3724v2  The problem of Hybrid Linear Modeling (HLM) is...  stat
# ...             ...                                                ...   ...
# 22534  1610.09659v1  We propose a methodology to explore and measur...  stat
# 22384  1605.03267v2  We present a new method for estimating multiva...  stat
# 32462   1112.1125v2  Although exploratory behaviors are ubiquitous ...    cs
# 7490   1801.05512v1  Survival analysis/time-to-event models are ext...  stat
# 6763   1705.10770v1  Forward-backward selection is one of the most ...    cs
#
#                                                    title  year  \
# 14123  Parameters Optimization of Deep Learning Model...  2017
# 9643   An extended Perona-Malik model based on probab...  2016
# 12010  Online Adaptive Machine Learning Based Algorit...  2017
# 16344  An Empirical Comparison of Simple Domain Adapt...  2017
# 37972  Foundations of a Multi-way Spectral Clustering...  2008
# ...                                                  ...   ...
# 22534  Exploring and measuring non-linear correlation...  2016
# 22384  Generalized Sparse Precision Matrix Selection ...  2016
# 32462  Learning in embodied action-perception loops t...  2011
# 7490   Deep Neural Networks for Survival Analysis Bas...  2018
# 6763      Forward-Backward Selection with Early Dropping  2017
#
#                                                 keywords
# 14123  [successfully, translation, manufacturing, rec...
# 9643   [successful, restoring, reinterpret, extension...
# 12010  [regression, volatility, algorithm, derivation...
# 16344  [adaptation, translation, approaches, augmente...
# 37972  [subspaces, different, strategies, justifying,...
# ...                                                  ...
# 22534  [methodology, correlations, variables, methodo...
# 22384  [estimating, multivariate, stationary, precisi...
# 32462  [exploratory, behaviors, ubiquitous, computati...
# 7490   [analysistime, extremely, companies, therefore...
# 6763   [selection, selection, algorithms, available, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14123    [successfully, translation, manufacturing, rec...
# 9643     [successful, restoring, reinterpret, extension...
# 12010    [regression, volatility, algorithm, derivation...
# 16344    [adaptation, translation, approaches, augmente...
# 37972    [subspaces, different, strategies, justifying,...
#                                ...
# 11782    [developed, inspiration, implementing, structu...
# 6757     [embeddings, processing, representations, enca...
# 2506     [practical, nonlinear, probabilistic, regressi...
# 11697    [memberships, introduce, discovery, generaliza...
# 37873    [naturally, unobserved, hierarchical, structur...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8831 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5e0749c4-a6d9-4a1a-89cb-5ae718244217" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e0749c4-a6d9-4a1a-89cb-5ae718244217")) {                    Plotly.newPlot(                        "5e0749c4-a6d9-4a1a-89cb-5ae718244217",                        [{"x":["approaches","successful","techniques","consuming","computational","performance","successfully","technique","important","appropriately","recognition","experiments","manufacturing","application","resources","exploration","influence","collected","occupants","illustrate","preliminary","specifically","parameter","parameters","translation","configurations","nonetheless","potential","locations","decreased","optimization","efficient","landscape","algorithm","computation","expectation","maximization","diffusivity","algorithmically","computing","expectations","modification","approximations","uncertainties","relaxations","unmodified","numerical","resemblance","resulting","computationally","conditional","restoration","equations","procedure","probabilistic","objective","restoring","extensions","reinterpret","framework","diffusion","stationary","maintenance","derivation","accelerate","implement","implementation","enhancements","volatility","programmable","demonstrate","sensitivity","regression","intensive","competing","embedding","outperforms","presented","empirically","shortcomings","comparison","adaptation","empirical","augmented","artificial","curvature","theoretical","foundations","justifying","probability","concentrated","different","clustering","interaction","practically","strategies","subspaces","distributions","underlying","combination","applications","auxiliary","minimization","compositional","minimizing","nonconvex","nonlinear","compositions","accelerated","algorithms","convergence","nonsmooth","generated","iterations","estimation","solutions","involving","programming","interplay","gradients","classical","stochastic","composition","functions","ambiguous","thousands","performed","addressing","collecting","bottleneck","questions","assistance","inherently","preferred","alternative","annotation","inaccuracies","pioneered","deformable","challenges","practical","perception","appearance","automatically","sometimes","localizing","regarding","challenge","annotations","available","annotated","classifiers","detection","precision","supervised","unsupervised","cumbersome","investigate","probabilities","psychological","independent","arbitrary","normative","representing","supported","estimating","simplified","relations","variations","sufficient","conditions","unobserved","normatively","contribution","increasingly","algorithmic","assignment","considerations","unfairness","properties","perceptions","implications","predicting","judgments","assessment","prediction","decisions","considerable","discrimination","accurately","relevance","dimensional","identifies","reliability","recidivism","understand","recursively","structure","ensembles","classification"],"y":[465,70,372,31,271,893,84,268,339,14,370,586,6,244,75,53,70,72,2,79,45,154,118,257,110,26,9,149,44,8,319,395,15,819,129,39,34,1,4,138,6,29,36,11,8,3,78,2,147,85,93,17,23,118,146,179,4,53,2,512,21,25,8,14,24,56,126,4,2,4,551,36,121,35,22,110,272,175,80,15,118,60,166,36,134,13,169,10,1,146,6,780,149,82,13,89,19,110,127,121,399,22,69,23,39,7,54,6,14,579,129,1,180,30,206,143,49,133,6,27,105,132,28,219,26,36,128,22,12,23,81,14,23,17,107,51,2,4,20,118,132,40,70,171,21,11,39,171,63,312,64,108,344,90,219,182,4,158,59,12,114,79,4,54,20,66,21,82,83,63,129,6,1,72,56,44,18,7,0,211,1,33,91,9,47,241,54,42,18,71,38,182,23,11,1,73,12,356,18,505],"type":"bar"},{"x":["approaches","successful","techniques","consuming","computational","performance","successfully","techniqu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dichotomy</span> <span style=''>for</span> <span style=''>2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraint</span> <span style=''>Forbidden</span> <span style=''>CSP</span> <span style=''>Patterns</span> <br/><br/><span style=''>Although</span> <span style=''>the</span> <span style=''>CSP</span> <span style=''>(constraint</span> <span style='background-color:rgba(0, 255, 0, 0.846153846153846);'>satisfaction</span> <span style=''>problem)</span> <span style=''>is</span> <span style=''>NP</span> <span style=''>complete</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>are</span> <span style=''>binary</span> <span style=''>certain</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4794520547945205);'>instances</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.36708860759493667);'>tractable</span> <span style=''>We</span> <span style=''>study</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4794520547945205);'>instances</span> <span style=''>defined</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excluding</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>subproblems</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>led</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>of</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.36708860759493667);'>tractable</span> <span style=''>classes</span> <span style=''>The</span> <span style=''>complete</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>characterisation</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.36708860759493667);'>tractable</span> <span style=''>classes</span> <span style=''>defined</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>forbidding</span> <span style=''>patterns</span> <span style=''>(where</span> <span style=''>a</span> <span style=''>pattern</span> <span style=''>is</span> <span style=''>simply</span> <span style=''>a</span> <span style=''>compact</span> <span style='background-color:rgba(0, 255, 0, 0.38939670932358317);'>representation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>subproblems)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.38618925831202044);'>challenging</span> <span style=''>problem</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dichotomy</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>forbidden</span> <span style=''>patterns</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>consisting</span> <span style=''>of</span> <span style=''>either</span> <span style=''>one</span> <span style=''>or</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>This</span> <span style=''>has</span> <span style=''>allowed</span> <span style=''>us</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.36708860759493667);'>tract ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>Sieve</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intuitively</span> <span style=''>data</span> <span style=''>is</span> <span style=''>passed</span> <span style=''>through</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>progressively</span> <span style=''>fine</span> <span style=''>grained</span> <span style=''>sieves</span> <span style=''>Each</span> <span style=''>layer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sieve</span> <span style=''>recovers</span> <span style=''>a</span> <span style=''>single</span> <span style=''>latent</span> <span style=''>factor</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>informative</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>The</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformed</span> <span style=''>after</span> <span style=''>each</span> <span style=''>pass</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexplained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>trickles</span> <span style=''>down</span> <span style=''>to</span> <span style=''>the</span> <span style=''>next</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ultimately</span> <span style=''>we</span> <span style=''>are</span> <span style=''>left</span> <span style=''>with</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>factors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explaining</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>original</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remainder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>noise</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3647058823529413);'>Nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.32142857142857134);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>Using</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3647058823529413);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3807106598984772);'>dimension</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.32142857142857134);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>Nonlinearity</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>specifying</span> <span style='background-color:rgba(0, 255, 0, 0.35064935064935066);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style=''>matrices</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.35064935064935066);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>locations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>type</span> <span style=''>prior</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>is</span> <span style=''>made</span> <span style=''>feasible</span> <span style=''>by</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>von</span> <span style=''>Mises</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3510324483775812);'>distributions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>Using</span> <span style=''>Smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Geodesics</span> <br/><br/><span style=''>Existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>adept</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>revealing</span> <span style=''>hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>arising</span> <span style=''>from</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>and</span> <span style=''>thereby</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>producing</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>classic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>using</span> <span style=''>such</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>may</span> <span style=''>distort</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>and</span> <span style=''>thereby</span> <span style=''>produce</span> <span style=''>an</span> <span style=''>unfaithful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>Herein</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geodesics</span> <span style=''>that</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>treat</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>which</span> <span style=''>manifold</span> <span style='background- ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12205567451820129)
# 	information (0.24803711634546752)
# 	architecture (0.08636688079942897)
# 	representation (0.13561741613133477)
# 	segmentation (0.07458957887223412)
# 	processing (0.10778015703069237)
# 	detection (0.12276945039257674)
# 	different (0.278372591006424)
# 	convolutional (0.13383297644539616)
# 	recognition (0.13204853675945752)
#
# Some Statistics words are:
# 	stochastic (0.13263263263263264)
# 	theoretical (0.15465465465465467)
# 	variables (0.14064064064064064)
# 	algorithm (0.3918918918918919)
# 	estimation (0.1806806806806807)
# 	distribution (0.1816816816816817)
# 	statistical (0.16666666666666666)
# 	dimensional (0.18368368368368368)
# 	inference (0.2022022022022022)
# 	regression (0.17617617617617617)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cf8484ec-e497-44a7-941f-07684f254302" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf8484ec-e497-44a7-941f-07684f254302")) {                    Plotly.newPlot(                        "cf8484ec-e497-44a7-941f-07684f254302",                        [{"x":["approaches","successful","techniques","consuming","computational","performance","successfully","technique","important","appropriately","recognition","experiments","manufacturing","application","resources","exploration","influence","collected","occupants","illustrate","preliminary","specifically","parameter","parameters","translation","configurations","nonetheless","potential","locations","decreased","optimization","efficient","landscape","algorithm","computation","expectation","maximization","diffusivity","algorithmically","computing","expectations","modification","approximations","uncertainties","relaxations","unmodified","numerical","resemblance","resulting","computationally","conditional","restoration","equations","procedure","probabilistic","objective","restoring","extensions","reinterpret","framework","diffusion","stationary","maintenance","derivation","accelerate","implement","implementation","enhancements","volatility","programmable","demonstrate","sensitivity","regression","intensive","competing","embedding","outperforms","presented","empirically","shortcomings","comparison","adaptation","empirical","augmented","artificial","curvature","theoretical","foundations","justifying","probability","concentrated","different","clustering","interaction","practically","strategies","subspaces","distributions","underlying","combination","applications","auxiliary","minimization","compositional","minimizing","nonconvex","nonlinear","compositions","accelerated","algorithms","convergence","nonsmooth","generated","iterations","estimation","solutions","involving","programming","interplay","gradients","classical","stochastic","composition","functions","ambiguous","thousands","performed","addressing","collecting","bottleneck","questions","assistance","inherently","preferred","alternative","annotation","inaccuracies","pioneered","deformable","challenges","practical","perception","appearance","automatically","sometimes","localizing","regarding","challenge","annotations","available","annotated","classifiers","detection","precision","supervised","unsupervised","cumbersome","investigate","probabilities","psychological","independent","arbitrary","normative","representing","supported","estimating","simplified","relations","variations","sufficient","conditions","unobserved","normatively","contribution","increasingly","algorithmic","assignment","considerations","unfairness","properties","perceptions","implications","predicting","judgments","assessment","prediction","decisions","considerable","discrimination","accurately","relevance","dimensional","identifies","reliability","recidivism","understand","recursively","structure","ensembles","classification","classifier","selection","distinguish","sophisticated","published","decomposing","effectiveness","collection","coefficients","calculate","collaborative","filtering","correlation","recommendation","technology","representations","represented","extremely","universal","representation","sentences","languages","integrated","confidence","landscapes","significant","persistence","nonparametric","distribution","bootstrap","simulation","variables","intervals","improvement","estimator","approximate","analogues","transduction","generating","structures","recurrent","continuously","differentiable","phenomena","architectures","traditional","synthetic","demonstrated","representational","unbounded","generalisation","developed","evaluation","scheduling","separating","determine ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unfairness
# 	missforest
# 	retrospective
# 	imputations
# 	blockmodels
# 	textitnon
# 	archetypes
# 	initialise
# 	amortised
# 	propensity
# 	confounders
# 	transferability
# 	dissimilarities
# 	individualized
# 	frequentist
# 	regularised
# 	criterions
# 	blockmodel
# 	laplacians
# 	optionally
# Some words which never appear in Statistics papers:
# 	occupants
# 	inaccuracies
# 	localizing
# 	psychological
# 	transduction
# 	simplicial
# 	realisable
# 	ramifications
# 	touchscreens
# 	determinism
# 	organisms
# 	caenorhabditis
# 	fluorescent
# 	brightfield
# 	geographic
# 	geolocation
# 	mammography
# 	regulated
# 	specimens
# 	deforming

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069273502961849e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
